# %% [markdown]
# # TD PYTHON B3

# %% [markdown]
# # EXERCICES

# %% [markdown]
# ### 1-Ecrire une fonction qui prends un nombre et le mets au carré.
# après un input ecrire le resultat sous la forme("le carré de (nombre-input) est (valeur au carré)")

# %% [markdown]
# ### 2-Ecrire une fonction qui prend 2 nombres pour faire une addition et multiplication des 2
# puis apres 2 inputs ecrire le resultat sous la forme("multiplication(chiffre) addition(chiffre)"

# %% [markdown]
# ### 3-Ressayez exemple 2 avec lambda

# %% [markdown]
# ### 4-Ecrire une fonction qui arrondit les nombres au carré
# et appliquez la fonction a une liste d entiers entre -20 et 20

# %% [markdown]
# ### 5-Ecrire une fonction qui prends un nombre et calcule le diametre la surface et la circonference

# %% [markdown]
# ### 6-Ecrire une fonction qui prends 2 chiffres un negatif et un positif en input et retournes une liste de nombres positifs et pairs

# %% [markdown]
# ### 7- avec Filter et lambda Ecrire une fonction qui prends une liste et retourne les nombresdivisibles par 2

# %% [markdown]
# ### 8- Ecrire une fonction qui renverse un string
